# %% [markdown]
# <h3>Consider the given text dataset. Implement different text processing techniques and identify the most
# important keywords from the text. Display a word cloud from the same.</h4>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from PIL import Image
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
# !pip install nltk
# !pip install wordcloud

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mdjun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwordlt = stopwords.words("english")

# %%
file = open("./Dataset/Agatha.txt",'r').read()

# %%
file
# Out:
# 'Agatha Christie - Death On The Nile\nPART ONE\nCHAPTER 1\nLinnet Ridgeway!\n"That\'s Her." said Mr. Burnaby, the landlord of the Three Crowns.\nHe nudged his companion.\nThe two men stared with round bucolic eyes and slightly open mouths.\nA big scarlet Rolls-Royce had just stopped in front of the local post office.\nA girl jumped out, a girl without a hat and wearing a frock that looked (but only looked) simple. A girl\nwith golden hair and straight autocratic features--a girl with a lovely shape--a girl such as was seldom\nseen in MaltonunderWode.\nWith a quick imperative step she passed into the post office.\n"That\'s her!\'! said Mr. Burnaby again. And he went on in a low awed voice.\n"Millions she\'s got .... Going to spend thousands on the place. Swimming pools there\'s going to be, and\nItalian gardens and a ballroom and a half of the house pulled down and rebuilt . . ." "She\'ll bring money\ninto the town," said his friend.\nHe was a lean seedy-looking man. His tone was envious and grudging.\nMr. Burnaby agreed.\n"Yes, it\'s a great thing for Malton-under-Wode. A great thing it is." Mr. Burnaby was complacent about\nit. "Wake us all up proper," he added.\n"Bit of a difference from Sir George," said the other.\n"Ah, it was the \'orses did for him," said Mr. Burnaby indulgently. "Never \'ad no luck." "What did he get\nfor the place?" "A cool sixty thousand, so I\'ve heard." The lean man whistled.\nMr. Burnaby went on triumphantly: "And they say she\'ll have spent another sixty thousand before she\'s\nfinished!" "Wicked!" said the lean man. "Where\'d she get all that money from?" "America, so I\'ve heard.\nHer mother was the only daughter of one of those millionaire blokes. Quite like the pictures, isn\'t it?" The\ngirl came out of the post office and climbed into the car.\nAs she drove off the lean man followed her with his eyes.\nHe muttered: "It seems all wrong to me---her looking like that. Money and looks--it\'s too much! Ifa girl\'s\nas rich as that she\'s no right to be a good-looker as well. And she is a good-looker... Got everything that\ngirl has. Doesn\'t seem fair..." ii\n\n\x0cExtract from the social column of the Daily Blague.\n"Among those supping at Chez Ma Tante I noticed beautiful Linnet Ridgeway. She was with the Hon.\nJoanna Southwood, Lord Windlesham and Mr.\nToby Bryce. Miss Ridgeway, as everyone knows, is the daughter of Melhuish Ridgeway who married\nAnna Hartz. She inherits from her grandfather, Leopold Hartz, an immense fortune. The lovely Linnet is\nthe sensation of the moment, and it is rumoured that an engagement may be announced shortly. Certainly\nLord Windlesham seemed very pris!"\nThe Hon. Joanna Southwood said: "Darling, I think it\'s going to be all perfectly marvellous!" She was\nsitting in Linnet Ridgeway\'s bedroom at Wode Hall.\nFrom the window the eye passed over the gardens to open country with blue shadows of woodlands.\n"It\'s rather perfect, isn\'t it?" said Linnet.\nShe leaned her arms on the window-sill. Her face was eager, alive, dynamic.\nBeside her, Joanna Southwood seemed, somehow, a little dim--a tall, thin young woman of\ntwenty-seven, with a long clever face and freakishly plucked eyebrows.\n"And you\'ve done so much in the time! Did you have lots of architects and things?" "Three." "What are\narchitects like? I don\'t think I\'ve ever met any." "They were all right. I found them rather unpractical\nsometimes." "Darling, you soon put that right! You are the most practical creature!" Joanna picked up a\nstring of pearls from the dressing-table.\n"I suppose these are real, aren\'t they, Linnet?" "Of course." "I know it\'s \'of course\' to you, my sweet, but\nit wouldn\'t be to most people.\nHeavily cultured or even Woolworth! Darling, they really are incredible, so exquisitely matched. They\nmust be worth the most fabulous sums!" "Rather vulgar, you think?" "No, not at all--just pure beauty.\nWhat are they worth?" "About fifty thousand." "What a lovely lot of money! Aren ...

# %%
len(file)
# Out:
# 439857

# %%
# # Download the punkt tokenizer model
# nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\mdjun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# #tonkenize word
words = word_tokenize(file)

# %%
len(words)
# Out:
# 101098

# %%
#Punctuation removal
word_no_punc = []
for word in words:
    if(word.isalpha()):
        word_no_punc.append(word.lower())
len(word_no_punc)
# Out:
# 77196

# %%
word_no_punc
# Out:
# ['agatha',
#  'christie',
#  'death',
#  'on',
#  'the',
#  'nile',
#  'part',
#  'one',
#  'chapter',
#  'linnet',
#  'ridgeway',
#  'that',
#  'her',
#  'said',
#  'burnaby',
#  'the',
#  'landlord',
#  'of',
#  'the',
#  'three',
#  'crowns',
#  'he',
#  'nudged',
#  'his',
#  'companion',
#  'the',
#  'two',
#  'men',
#  'stared',
#  'with',
#  'round',
#  'bucolic',
#  'eyes',
#  'and',
#  'slightly',
#  'open',
#  'mouths',
#  'a',
#  'big',
#  'scarlet',
#  'had',
#  'just',
#  'stopped',
#  'in',
#  'front',
#  'of',
#  'the',
#  'local',
#  'post',
#  'office',
#  'a',
#  'girl',
#  'jumped',
#  'out',
#  'a',
#  'girl',
#  'without',
#  'a',
#  'hat',
#  'and',
#  'wearing',
#  'a',
#  'frock',
#  'that',
#  'looked',
#  'but',
#  'only',
#  'looked',
#  'simple',
#  'a',
#  'girl',
#  'with',
#  'golden',
#  'hair',
#  'and',
#  'straight',
#  'autocratic',
#  'features',
#  'a',
#  'girl',
#  'with',
#  'a',
#  'lovely',
#  'shape',
#  'a',
#  'girl',
#  'such',
#  'as',
#  'was',
#  'seldom',
#  'seen',
#  'in',
#  'maltonunderwode',
#  'with',
#  'a',
#  'quick',
#  'imperative',
#  'step',
#  'she',
#  'passed',
#  'into',
#  'the',
#  'post',
#  'office',
#  'that',
#  'her',
#  'said',
#  'burnaby',
#  'again',
#  'and',
#  'he',
#  'went',
#  'on',
#  'in',
#  'a',
#  'low',
#  'awed',
#  'voice',
#  'millions',
#  'she',
#  'got',
#  'going',
#  'to',
#  'spend',
#  'thousands',
#  'on',
#  'the',
#  'place',
#  'swimming',
#  'pools',
#  'there',
#  'going',
#  'to',
#  'be',
#  'and',
#  'italian',
#  'gardens',
#  'and',
#  'a',
#  'ballroom',
#  'and',
#  'a',
#  'half',
#  'of',
#  'the',
#  'house',
#  'pulled',
#  'down',
#  'and',
#  'rebuilt',
#  'she',
#  'bring',
#  'money',
#  'into',
#  'the',
#  'town',
#  'said',
#  'his',
#  'friend',
#  'he',
#  'was',
#  'a',
#  'lean',
#  'man',
#  'his',
#  'tone',
#  'was',
#  'envious',
#  'and',
#  'grudging',
#  'burnaby',
#  'agreed',
#  'yes',
#  'it',
#  'a',
#  'great',
#  'thing',
#  'for',
#  'a',
#  'great',
#  'thing',
#  'it',
#  'is',
#  'burnaby',
#  'was',
#  'complacent',
#  'about',
#  'it',
#  'wake',
#  'us',
#  'all',
#  'up',
#  'proper',
#  'he',
#  'added',
#  'bit',
#  'of',
#  'a',
#  'difference',
#  'from',
#  'sir',
#  'george',
#  'said',
#  'the',
#  'other',
#  'ah',
#  'it',
#  'was',
#  'the',
#  'did',
#  'for',
#  'him',
#  'said',
#  'burnaby',
#  'indulgently',
#  'never',
#  'no',
#  'luck',
#  'what',
#  'did',
#  'he',
#  'get',
#  'for',
#  'the',
#  'place',
#  'a',
#  'cool',
#  'sixty',
#  'thousand',
#  'so',
#  'i',
#  'heard',
#  'the',
#  'lean',
#  'man',
#  'whistled',
#  'burnaby',
#  'went',
#  'on',
#  'triumphantly',
#  'and',
#  'they',
#  'say',
#  'she',
#  'have',
#  'spent',
#  'another',
#  'sixty',
#  'thousand',
#  'before',
#  'she',
#  'finished',
#  'wicked',
#  'said',
#  'the',
#  'lean',
#  'man',
#  'where',
#  'she',
#  'get',
#  'all',
#  'that',
#  'money',
#  'from',
#  'america',
#  'so',
#  'i',
#  'heard',
#  'her',
#  'mother',
#  'was',
#  'the',
#  'only',
#  'daughter',
#  'of',
#  'one',
#  'of',
#  'those',
#  'millionaire',
#  'blokes',
#  'quite',
#  'like',
#  'the',
#  'pictures',
#  'is',
#  'it',
#  'the',
#  'girl',
#  'came',
#  'out',
#  'of',
#  'the',
#  'post',
#  'office',
#  'and',
#  'climbed',
#  'into',
#  'the',
#  'car',
#  'as',
#  'she',
#  'drove',
#  'off',
#  'the',
#  'lean',
#  'man',
#  'followed',
#  'her',
#  'with',
#  'his',
#  'eyes',
#  'he',
#  'muttered',
#  'it',
#  'seems',
#  'all',
#  'wrong',
#  'to',
#  'me',
#  'looking',
#  'like',
#  'that',
#  'money',
#  'and',
#  'looks',
#  'it',
#  'too',
#  'much',
#  'ifa',
#  'girl',
#  'as',
#  'rich',
#  'as',
#  'that',
#  'she',
#  'no',
#  'right',
#  'to',
#  'be',
#  'a',
#  'as',
#  'well',
#  'and',
#  'she',
#  'is',
#  'a',
#  'got',
#  'everything',
#  'that',
#  'girl',
#  'has',
#  'does',
#  'seem',
#  'fair',
#  'ii',
#  'extract',
#  'from',
#  'the',
#  'social',
#  'column',
#  'of',
#  'the',
#  'daily',
#  'blague',
#  'among',
#  'those',
#  'supping',
#  'at',
#  'chez',
#  'ma',
#  'tante',
#  'i',
#  'noticed',
#  'beautiful',
#  'linnet',
#  'ridgeway',
#  'she',
#  'was',
#  'with',
#  'the',
#  'hon',
#  'joanna',
#  'southwood',
#  'lord',
#  'windlesham',
#  'and',
#  'toby',
#  'bryce',
#  'miss',
#  'ridgeway',
#  'as',
#  'everyone',
#  'knows',
#  'is',
#  'the',
#  'daughter',
#  'of',
#  'melhuish',
#  'ridgeway',
#  'who',
#  'married',
#  'anna',
#  'hartz',
#  'she',
#  'inherits',
#  'from',
#  'her',
#  'grandfather',
#  'leopold',
#  'hartz',
#  'an',
#  'immense',
#  'fortune',
#  'the',
#  'lovely',
#  'linnet',
#  'is',
#  'the',
#  'sensation',
#  'of',
#  'the',
#  'moment',
#  'and',
#  'it',
#  'is',
#  'rumoured',
#  'that',
#  'an',
#  'engagement',
#  'may',
#  'be',
#  'announced',
#  'shortly',
#  'certainly',
#  'lord',
#  'windlesham',
#  'seemed',
#  'very',
#  'pris',
#  'the',
#  'hon',
#  'joanna',
#  'southwood',
#  'said',
#  'darling',
#  'i',
#  'think',
#  'it',
#  'going',
#  'to',
#  'be',
#  'all',
#  'perfectly',
#  'marvellous',
#  'she',
#  'was',
#  'sitting',
#  'in',
#  'linnet',
#  'ridgeway',
#  'bedroom',
#  'at',
#  'wode',
#  'hall',
#  'from',
#  'the',
#  'window',
#  'the',
#  'eye',
#  'passed',
#  'over',
#  'the',
#  'gardens',
#  'to',
#  'open',
#  'country',
#  'with',
#  'blue',
#  'shadows',
#  'of',
#  'woodlands',
#  'it',
#  'rather',
#  'perfect',
#  'is',
#  'it',
#  'said',
#  'linnet',
#  'she',
#  'leaned',
#  'her',
#  'arms',
#  'on',
#  'the',
#  'her',
#  'face',
#  'was',
#  'eager',
#  'alive',
#  'dynamic',
#  'beside',
#  'her',
#  'joanna',
#  'southwood',
#  'seemed',
#  'somehow',
#  'a',
#  'little',
#  'dim',
#  'a',
#  'tall',
#  'thin',
#  'young',
#  'woman',
#  'of',
#  'with',
#  'a',
#  'long',
#  'clever',
#  'face',
#  'and',
#  'freakishly',
#  'plucked',
#  'eyebrows',
#  'and',
#  'you',
#  'done',
#  'so',
#  'much',
#  'in',
#  'the',
#  'time',
#  'did',
#  'you',
#  'have',
#  'lots',
#  'of',
#  'architects',
#  'and',
#  'things',
#  'three',
#  'what',
#  'are',
#  'architects',
#  'like',
#  'i',
#  'do',
#  'think',
#  'i',
#  'ever',
#  'met',
#  'any',
#  'they',
#  'were',
#  'all',
#  'right',
#  'i',
#  'found',
#  'them',
#  'rather',
#  'unpractical',
#  'sometimes',
#  'darling',
#  'you',
#  'soon',
#  'put',
#  'that',
#  'right',
#  'you',
#  'are',
#  'the',
#  'most',
#  'practical',
#  'creature',
#  'joanna',
#  'picked',
#  'up',
#  'a',
#  'string',
#  'of',
#  'pearls',
#  'from',
#  'the',
#  'i',
#  'suppose',
#  'these',
#  'are',
#  'real',
#  'are',
#  'they',
#  'linnet',
#  'of',
#  'course',
#  'i',
#  'know',
#  'it',
#  'course',
#  'to',
#  'you',
#  'my',
#  'sweet',
#  'but',
#  'it',
#  'would',
#  'be',
#  'to',
#  'most',
#  'people',
#  'heavily',
#  'cultured',
#  'or',
#  'even',
#  'woolworth',
#  'darling',
#  'they',
#  'really',
#  'are',
#  'incredible',
#  'so',
#  'exquisitely',
#  'matched',
#  'they',
#  'must',
#  'be',
#  'worth',
#  'the',
#  'most',
#  'fabulous',
#  'sums',
#  'rather',
#  'vulgar',
#  'you',
#  'think',
#  'no',
#  'not',
#  'at',
#  'all',
#  'just',
#  'pure',
#  'beauty',
#  'what',
#  'are',
#  'they',
#  'worth',
#  'about',
#  'fifty',
#  'thousand',
#  'what',
#  'a',
#  'lovely',
#  'lot',
#  'of',
#  'money',
#  'are',
#  'you',
#  'afraid',
#  'of',
#  'having',
#  'them',
#  'stolen',
#  'no',
#  'i',
#  'always',
#  'wear',
#  'them',
#  'and',
#  'anyway',
#  'they',
#  'insured',
#  'let',
#  'me',
#  'wear',
#  'them',
#  'till',
#  'will',
#  'you',
#  'darling',
#  'it',
#  'would',
#  'give',
#  'me',
#  'such',
#  'a',
#  'thrill',
#  'linnet',
#  'laughed',
#  'of',
#  'course',
#  'if',
#  'you',
#  'like',
#  'you',
#  'know',
#  'linnet',
#  'i',
#  'really',
#  'do',
#  'envy',
#  'you',
#  'you',
#  'simply',
#  'got',
#  'everything',
#  'here',
#  'you',
#  'are',
#  'at',
#  'twenty',
#  'your',
#  'own',
#  'mistress',
#  'with',
#  'any',
#  'amount',
#  'of',
#  'money',
#  'looks',
#  'superb',
#  'health',
#  'you',
#  'even',
#  'got',
#  'brains',
#  'when',
#  'are',
#  'you',
#  'next',
#  'june',
#  'i',
#  'shall',
#  'have',
#  'a',
#  'grand',
#  'party',
#  'in',
#  'london',
#  'and',
#  'then',
#  'are',
#  'you',
#  'going',
#  'to',
#  'marry',
#  'charles',
#  'windlesham',
#  'all',
#  'the',
#  'dreadful',
#  'little',
#  'gossip',
#  'writers',
#  'are',
#  'getting',
#  'so',
#  'excited',
#  'about',
#  'it',
#  'and',
#  'he',
#  'really',
#  'is',
#  'frightfully',
#  'devoted',
#  'linnet',
#  'shrugged',
#  'her',
#  'shoulders',
#  'i',
#  'do',
#  'know',
#  'i',
#  'do',
#  'really',
#  'want',
#  'to',
#  'marry',
#  'any',
#  'one',
#  'yet',
#  'darling',
#  'how',
#  'right',
#  'you',
#  'are',
#  'it',
#  'never',
#  'quite',
#  'the',
#  'same',
#  'afterwards',
#  'is',
#  'it',
#  'the',
#  'telephone',
#  'shrilled',
#  'and',
#  'linnet',
#  'went',
#  'to',
#  'it',
#  'yes',
#  'yes',
#  'the',
#  'butler',
#  'voice',
#  'answered',
#  'her',
#  'miss',
#  'de',
#  'bellefort',
#  'is',
#  'on',
#  'the',
#  'line',
#  'shall',
#  'i',
#  'put',
#  'her',
#  'through',
#  'bellefort',
#  'oh',
#  'of',
#  'course',
#  'yes',
#  'put',
#  'her',
#  'through',
#  'a',
#  'click',
#  'and',
#  'a',
#  'voice',
#  'an',
#  'eager',
#  'soft',
#  'slightly',
#  'breathless',
#  'voice',
#  'hallo',
#  'is',
#  'that',
#  'miss',
#  'ridgeway',
#  'i',
#  'have',
#  'heard',
#  'anything',
#  'i',
#  'know',
#  'it',
#  'awful',
#  'linnet',
#  'i',
#  'want',
#  'to',
#  'see',
#  'darling',
#  'ca',
#  'you',
#  'come',
#  'down',
#  'here',
#  'my',
#  'that',
#  'just',
#  'what',
#  'i',
#  'want',
#  'to',
#  'do',
#  'well',
#  'jump',
#  'into',
#  'a',
#  'train',
#  'or',
#  'a',
#  'car',
#  'right',
#  'i',
#  'will',
#  'a',
#  'frightfully',
#  'dilapidated',
#  'of',
#  'you',
#  'for',
#  'ages',
#  'and',
#  'you',
#  'terribly',
#  'new',
#  'toy',
#  'i',
#  'love',
#  'to',
#  'show',
#  'it',
#  'to',
#  'you',
#  'i',
#  'bought',
#  'it',
#  'for',
#  'fifteen',
#  'pounds',
#  'and',
#  'some',
#  'days',
#  'it',
#  'goes',
#  'beautifully',
#  'but',
#  'it',
#  'has',
#  'moods',
#  'if',
#  'i',
#  'have',
#  'arrived',
#  'by',
#  'you',
#  'know',
#  'it',
#  'had',
#  'a',
#  'mood',
#  'so',
#  'long',
#  'my',
#  'sweet',
#  'linnet',
#  'replaced',
#  'the',
#  'receiver',
#  'she',
#  'crossed',
#  'back',
#  'to',
#  'joanna',
#  'that',
#  'my',
#  'oldest',
#  'friend',
#  'jacqueline',
#  'de',
#  'bellefort',
#  'we',
#  'were',
#  'together',
#  'at',
#  'a',
#  'convent',
#  'in',
#  'paris',
#  'she',
#  'had',
#  'the',
#  'most',
#  'terribly',
#  'bad',
#  'luck',
#  'her',
#  'father',
#  'was',
#  'a',
#  'french',
#  'count',
#  'her',
#  'mother',
#  'was',
#  'american',
#  'a',
#  'southerner',
#  'the',
#  'father',
#  'went',
#  'off',
#  'with',
#  'some',
#  'woman',
#  'and',
#  'her',
#  'mother',
#  'lost',
#  'all',
#  'her',
#  'money',
#  'in',
#  'the',
#  'wall',
#  'street',
#  'crash',
#  'jackie',
#  'was',
#  'left',
#  'absolutely',
#  'broke',
#  'i',
#  'do',
#  ...]

# %%
#Stopwords removal
clean_words = []
for  word in word_no_punc:
    if word not in stopwordlt:
        clean_words.append(word)
len(clean_words)
# Out:
# 37715

# %%
clean_words
# Out:
# ['agatha',
#  'christie',
#  'death',
#  'nile',
#  'part',
#  'one',
#  'chapter',
#  'linnet',
#  'ridgeway',
#  'said',
#  'burnaby',
#  'landlord',
#  'three',
#  'crowns',
#  'nudged',
#  'companion',
#  'two',
#  'men',
#  'stared',
#  'round',
#  'bucolic',
#  'eyes',
#  'slightly',
#  'open',
#  'mouths',
#  'big',
#  'scarlet',
#  'stopped',
#  'front',
#  'local',
#  'post',
#  'office',
#  'girl',
#  'jumped',
#  'girl',
#  'without',
#  'hat',
#  'wearing',
#  'frock',
#  'looked',
#  'looked',
#  'simple',
#  'girl',
#  'golden',
#  'hair',
#  'straight',
#  'autocratic',
#  'features',
#  'girl',
#  'lovely',
#  'shape',
#  'girl',
#  'seldom',
#  'seen',
#  'maltonunderwode',
#  'quick',
#  'imperative',
#  'step',
#  'passed',
#  'post',
#  'office',
#  'said',
#  'burnaby',
#  'went',
#  'low',
#  'awed',
#  'voice',
#  'millions',
#  'got',
#  'going',
#  'spend',
#  'thousands',
#  'place',
#  'swimming',
#  'pools',
#  'going',
#  'italian',
#  'gardens',
#  'ballroom',
#  'half',
#  'house',
#  'pulled',
#  'rebuilt',
#  'bring',
#  'money',
#  'town',
#  'said',
#  'friend',
#  'lean',
#  'man',
#  'tone',
#  'envious',
#  'grudging',
#  'burnaby',
#  'agreed',
#  'yes',
#  'great',
#  'thing',
#  'great',
#  'thing',
#  'burnaby',
#  'complacent',
#  'wake',
#  'us',
#  'proper',
#  'added',
#  'bit',
#  'difference',
#  'sir',
#  'george',
#  'said',
#  'ah',
#  'said',
#  'burnaby',
#  'indulgently',
#  'never',
#  'luck',
#  'get',
#  'place',
#  'cool',
#  'sixty',
#  'thousand',
#  'heard',
#  'lean',
#  'man',
#  'whistled',
#  'burnaby',
#  'went',
#  'triumphantly',
#  'say',
#  'spent',
#  'another',
#  'sixty',
#  'thousand',
#  'finished',
#  'wicked',
#  'said',
#  'lean',
#  'man',
#  'get',
#  'money',
#  'america',
#  'heard',
#  'mother',
#  'daughter',
#  'one',
#  'millionaire',
#  'blokes',
#  'quite',
#  'like',
#  'pictures',
#  'girl',
#  'came',
#  'post',
#  'office',
#  'climbed',
#  'car',
#  'drove',
#  'lean',
#  'man',
#  'followed',
#  'eyes',
#  'muttered',
#  'seems',
#  'wrong',
#  'looking',
#  'like',
#  'money',
#  'looks',
#  'much',
#  'ifa',
#  'girl',
#  'rich',
#  'right',
#  'well',
#  'got',
#  'everything',
#  'girl',
#  'seem',
#  'fair',
#  'ii',
#  'extract',
#  'social',
#  'column',
#  'daily',
#  'blague',
#  'among',
#  'supping',
#  'chez',
#  'tante',
#  'noticed',
#  'beautiful',
#  'linnet',
#  'ridgeway',
#  'hon',
#  'joanna',
#  'southwood',
#  'lord',
#  'windlesham',
#  'toby',
#  'bryce',
#  'miss',
#  'ridgeway',
#  'everyone',
#  'knows',
#  'daughter',
#  'melhuish',
#  'ridgeway',
#  'married',
#  'anna',
#  'hartz',
#  'inherits',
#  'grandfather',
#  'leopold',
#  'hartz',
#  'immense',
#  'fortune',
#  'lovely',
#  'linnet',
#  'sensation',
#  'moment',
#  'rumoured',
#  'engagement',
#  'may',
#  'announced',
#  'shortly',
#  'certainly',
#  'lord',
#  'windlesham',
#  'seemed',
#  'pris',
#  'hon',
#  'joanna',
#  'southwood',
#  'said',
#  'darling',
#  'think',
#  'going',
#  'perfectly',
#  'marvellous',
#  'sitting',
#  'linnet',
#  'ridgeway',
#  'bedroom',
#  'wode',
#  'hall',
#  'window',
#  'eye',
#  'passed',
#  'gardens',
#  'open',
#  'country',
#  'blue',
#  'shadows',
#  'woodlands',
#  'rather',
#  'perfect',
#  'said',
#  'linnet',
#  'leaned',
#  'arms',
#  'face',
#  'eager',
#  'alive',
#  'dynamic',
#  'beside',
#  'joanna',
#  'southwood',
#  'seemed',
#  'somehow',
#  'little',
#  'dim',
#  'tall',
#  'thin',
#  'young',
#  'woman',
#  'long',
#  'clever',
#  'face',
#  'freakishly',
#  'plucked',
#  'eyebrows',
#  'done',
#  'much',
#  'time',
#  'lots',
#  'architects',
#  'things',
#  'three',
#  'architects',
#  'like',
#  'think',
#  'ever',
#  'met',
#  'right',
#  'found',
#  'rather',
#  'unpractical',
#  'sometimes',
#  'darling',
#  'soon',
#  'put',
#  'right',
#  'practical',
#  'creature',
#  'joanna',
#  'picked',
#  'string',
#  'pearls',
#  'suppose',
#  'real',
#  'linnet',
#  'course',
#  'know',
#  'course',
#  'sweet',
#  'would',
#  'people',
#  'heavily',
#  'cultured',
#  'even',
#  'woolworth',
#  'darling',
#  'really',
#  'incredible',
#  'exquisitely',
#  'matched',
#  'must',
#  'worth',
#  'fabulous',
#  'sums',
#  'rather',
#  'vulgar',
#  'think',
#  'pure',
#  'beauty',
#  'worth',
#  'fifty',
#  'thousand',
#  'lovely',
#  'lot',
#  'money',
#  'afraid',
#  'stolen',
#  'always',
#  'wear',
#  'anyway',
#  'insured',
#  'let',
#  'wear',
#  'till',
#  'darling',
#  'would',
#  'give',
#  'thrill',
#  'linnet',
#  'laughed',
#  'course',
#  'like',
#  'know',
#  'linnet',
#  'really',
#  'envy',
#  'simply',
#  'got',
#  'everything',
#  'twenty',
#  'mistress',
#  'amount',
#  'money',
#  'looks',
#  'superb',
#  'health',
#  'even',
#  'got',
#  'brains',
#  'next',
#  'june',
#  'shall',
#  'grand',
#  'party',
#  'london',
#  'going',
#  'marry',
#  'charles',
#  'windlesham',
#  'dreadful',
#  'little',
#  'gossip',
#  'writers',
#  'getting',
#  'excited',
#  'really',
#  'frightfully',
#  'devoted',
#  'linnet',
#  'shrugged',
#  'shoulders',
#  'know',
#  'really',
#  'want',
#  'marry',
#  'one',
#  'yet',
#  'darling',
#  'right',
#  'never',
#  'quite',
#  'afterwards',
#  'telephone',
#  'shrilled',
#  'linnet',
#  'went',
#  'yes',
#  'yes',
#  'butler',
#  'voice',
#  'answered',
#  'miss',
#  'de',
#  'bellefort',
#  'line',
#  'shall',
#  'put',
#  'bellefort',
#  'oh',
#  'course',
#  'yes',
#  'put',
#  'click',
#  'voice',
#  'eager',
#  'soft',
#  'slightly',
#  'breathless',
#  'voice',
#  'hallo',
#  'miss',
#  'ridgeway',
#  'heard',
#  'anything',
#  'know',
#  'awful',
#  'linnet',
#  'want',
#  'see',
#  'darling',
#  'ca',
#  'come',
#  'want',
#  'well',
#  'jump',
#  'train',
#  'car',
#  'right',
#  'frightfully',
#  'dilapidated',
#  'ages',
#  'terribly',
#  'new',
#  'toy',
#  'love',
#  'show',
#  'bought',
#  'fifteen',
#  'pounds',
#  'days',
#  'goes',
#  'beautifully',
#  'moods',
#  'arrived',
#  'know',
#  'mood',
#  'long',
#  'sweet',
#  'linnet',
#  'replaced',
#  'receiver',
#  'crossed',
#  'back',
#  'joanna',
#  'oldest',
#  'friend',
#  'jacqueline',
#  'de',
#  'bellefort',
#  'together',
#  'convent',
#  'paris',
#  'terribly',
#  'bad',
#  'luck',
#  'father',
#  'french',
#  'count',
#  'mother',
#  'american',
#  'southerner',
#  'father',
#  'went',
#  'woman',
#  'mother',
#  'lost',
#  'money',
#  'wall',
#  'street',
#  'crash',
#  'jackie',
#  'left',
#  'absolutely',
#  'broke',
#  'know',
#  'managed',
#  'get',
#  'along',
#  'last',
#  'two',
#  'years',
#  'joanna',
#  'polishing',
#  'deep',
#  'nails',
#  'friend',
#  'nail',
#  'pad',
#  'leant',
#  'back',
#  'head',
#  'one',
#  'side',
#  'scrutinising',
#  'effect',
#  'darling',
#  'drawled',
#  'wo',
#  'rather',
#  'tiresome',
#  'misfortunes',
#  'happen',
#  'friends',
#  'always',
#  'drop',
#  'sounds',
#  'heartless',
#  'saves',
#  'lot',
#  'trouble',
#  'later',
#  'always',
#  'want',
#  'borrow',
#  'money',
#  'else',
#  'start',
#  'business',
#  'get',
#  'terrible',
#  'clothes',
#  'paint',
#  'lampshades',
#  'batik',
#  'scarves',
#  'lost',
#  'money',
#  'drop',
#  'tomorrow',
#  'yes',
#  'darling',
#  'would',
#  'ca',
#  'say',
#  'honest',
#  'like',
#  'successful',
#  'people',
#  'find',
#  'true',
#  'nearly',
#  'everybody',
#  'people',
#  'wo',
#  'admit',
#  'say',
#  'ca',
#  'put',
#  'mary',
#  'emily',
#  'pamela',
#  'troubles',
#  'made',
#  'bitter',
#  'peculiar',
#  'poor',
#  'dear',
#  'beastly',
#  'joanna',
#  'make',
#  'like',
#  'every',
#  'one',
#  'else',
#  'make',
#  'obvious',
#  'reasons',
#  'sordid',
#  'american',
#  'trustees',
#  'pay',
#  'vast',
#  'allowance',
#  'every',
#  'quarter',
#  'wrong',
#  'jacqueline',
#  'said',
#  'linnet',
#  'sponge',
#  'wanted',
#  'help',
#  'wo',
#  'let',
#  'proud',
#  'devil',
#  'hurry',
#  'see',
#  'bet',
#  'wants',
#  'something',
#  'wait',
#  'see',
#  'sounded',
#  'excited',
#  'something',
#  'admitted',
#  'linnet',
#  'jackie',
#  'always',
#  'get',
#  'frightfully',
#  'worked',
#  'things',
#  'stuck',
#  'penknife',
#  'one',
#  'darling',
#  'thrilling',
#  'boy',
#  'teasing',
#  'dog',
#  'jackie',
#  'tried',
#  'get',
#  'stop',
#  'would',
#  'pulled',
#  'shook',
#  'much',
#  'stronger',
#  'last',
#  'whipped',
#  'penknife',
#  'plunged',
#  'right',
#  'awful',
#  'row',
#  'think',
#  'sounds',
#  'uncomfortable',
#  'linnet',
#  'maid',
#  'entered',
#  'room',
#  'murmured',
#  'word',
#  'apology',
#  'took',
#  'dress',
#  'wardrobe',
#  'went',
#  'room',
#  'matter',
#  'marie',
#  'asked',
#  'joanna',
#  'crying',
#  'poor',
#  'thing',
#  'know',
#  'told',
#  'wanted',
#  'marry',
#  'man',
#  'job',
#  'egypt',
#  'know',
#  'much',
#  'thought',
#  'better',
#  'make',
#  'sure',
#  'right',
#  'turned',
#  'wife',
#  'already',
#  'three',
#  'children',
#  'lot',
#  'enemies',
#  'must',
#  'make',
#  'linnet',
#  'enemies',
#  'linnet',
#  'looked',
#  'surprised',
#  'joanna',
#  'nodded',
#  'helped',
#  'cigarette',
#  'enemies',
#  'sweet',
#  'devastatingly',
#  'efficient',
#  'frightfully',
#  'good',
#  'right',
#  'thing',
#  'linnet',
#  'laughed',
#  'got',
#  'enemy',
#  'world',
#  'il',
#  'lord',
#  'windlesham',
#  'sat',
#  'cedar',
#  'tree',
#  'eyes',
#  'rested',
#  'graceful',
#  'proportions',
#  'wode',
#  'hall',
#  'nothing',
#  'mar',
#  'beauty',
#  'new',
#  'buildings',
#  'additions',
#  'sight',
#  'round',
#  'corner',
#  'fair',
#  'peaceful',
#  'sight',
#  'bathed',
#  'autumn',
#  'sunshine',
#  'nevertheless',
#  'gazed',
#  'longer',
#  'wode',
#  'hall',
#  'charles',
#  'windlesham',
#  'saw',
#  'instead',
#  'seemed',
#  'see',
#  'imposing',
#  'elizabethan',
#  'mansion',
#  'long',
#  'sweep',
#  'park',
#  'bleaker',
#  'background',
#  'family',
#  'seat',
#  'charltonbury',
#  'foreground',
#  'stood',
#  'figurea',
#  'girl',
#  'figure',
#  'bright',
#  'golden',
#  'hair',
#  'eager',
#  'confident',
#  'face',
#  'linnet',
#  'mistress',
#  'charltonbury',
#  'felt',
#  'hopeful',
#  'refusal',
#  'definite',
#  'refusal',
#  'little',
#  'plea',
#  'time',
#  'well',
#  'could',
#  'afford',
#  'wait',
#  'little',
#  'amazingly',
#  'suitable',
#  'whole',
#  'thing',
#  'certainly',
#  'advisable',
#  'marry',
#  'money',
#  'matter',
#  'necessity',
#  'could',
#  'regard',
#  'forced',
#  'put',
#  'feelings',
#  'one',
#  'side',
#  'loved',
#  'linnet',
#  'would',
#  'wanted',
#  'marry',
#  'even',
#  'practically',
#  'penniless',
#  'instead',
#  'one',
#  'richest',
#  'girls',
#  'england',
#  'fortunately',
#  'one',
#  'richest',
#  'girls',
#  'england',
#  'mind',
#  'played',
#  'attractive',
#  'plans',
#  'future',
#  'mastership',
#  'roxdale',
#  'perhaps',
#  'restoration',
#  'west',
#  'wing',
#  'need',
#  'let',
#  'scotch',
#  'shooting',
#  'charles',
#  'windlesham',
#  'dreamed',
#  'sun',
#  'four',
#  'dilapidated',
#  'little',
#  'stopped',
#  'sound',
#  'crunching',
#  'gravel',
#  'girl',
#  'got',
#  'small',
#  'slender',
#  'creature',
#  'mop',
#  'dark',
#  'hair',
#  'ran',
#  'steps',
#  'tugged',
#  'bell',
#  'minutes',
#  'later',
#  'ushered',
#  'long',
#  'stately',
#  'ecclesiastical',
#  'butler',
#  'saying',
#  'proper',
#  'mournful',
#  'intonation',
#  'miss',
#  'de',
#  'bellefort',
#  'linnet',
#  'jackie',
#  'windlesham',
#  'stood',
#  'little',
#  'aside',
#  'watching',
#  'sympathetically',
#  'fiery',
#  'little',
#  'creature',
#  'flung',
#  'upon',
#  'linnet',
#  'lord',
#  'windlesham',
#  'miss',
#  'de',
#  'bellefort',
#  'best',
#  'friend',
#  'pretty',
#  'child',
#  'thought',
#  'really',
#  'pretty',
#  'decidedly',
#  'attractive',
#  'dark',
#  'curly',
#  'hair',
#  'enormous',
#  'eyes',
#  'murmured',
#  'tactful',
#  'nothings',
#  'managed',
#  'unobtrusively',
#  'leave',
#  'two',
#  'friends',
#  'together',
#  'jacqueline',
#  'pouncedin',
#  'fashion',
#  'linnet',
#  'remembered',
#  'characteristic',
#  'windlesham',
#  'windlesham',
#  'man',
#  'papers',
#  'always',
#  'say',
#  'going',
#  'marry',
#  'linnet',
#  'linnet',
#  'murmured',
#  'perhaps',
#  'darling',
#  'glad',
#  'looks',
#  'nice',
#  'oh',
#  'make',
#  'mind',
#  'made',
#  'mind',
#  'yet',
#  'course',
#  'queens',
#  'always',
#  'proceed',
#  'due',
#  'deliberation',
#  'choosing',
#  'consort',
#  'ridiculous',
#  'jackie',
#  'queen',
#  'linnet',
#  'always',
#  'sa',
#  'majesty',
#  'la',
#  'reine',
#  'linette',
#  'linette',
#  'la',
#  'blonde',
#  'queen',
#  'confidante',
#  'trusted',
#  'maid',
#  'honour',
#  'nonsense',
#  'talk',
#  'jackie',
#  'darling',
#  'time',
#  'disappear',
#  'never',
#  'write',
#  'hate',
#  ...]

# %%
#join all the clean words to  form wordcloud
word_string = " ".join(clean_words)
word_string
# Out:
# 'agatha christie death nile part one chapter linnet ridgeway said burnaby landlord three crowns nudged companion two men stared round bucolic eyes slightly open mouths big scarlet stopped front local post office girl jumped girl without hat wearing frock looked looked simple girl golden hair straight autocratic features girl lovely shape girl seldom seen maltonunderwode quick imperative step passed post office said burnaby went low awed voice millions got going spend thousands place swimming pools going italian gardens ballroom half house pulled rebuilt bring money town said friend lean man tone envious grudging burnaby agreed yes great thing great thing burnaby complacent wake us proper added bit difference sir george said ah said burnaby indulgently never luck get place cool sixty thousand heard lean man whistled burnaby went triumphantly say spent another sixty thousand finished wicked said lean man get money america heard mother daughter one millionaire blokes quite like pictures girl came post office climbed car drove lean man followed eyes muttered seems wrong looking like money looks much ifa girl rich right well got everything girl seem fair ii extract social column daily blague among supping chez tante noticed beautiful linnet ridgeway hon joanna southwood lord windlesham toby bryce miss ridgeway everyone knows daughter melhuish ridgeway married anna hartz inherits grandfather leopold hartz immense fortune lovely linnet sensation moment rumoured engagement may announced shortly certainly lord windlesham seemed pris hon joanna southwood said darling think going perfectly marvellous sitting linnet ridgeway bedroom wode hall window eye passed gardens open country blue shadows woodlands rather perfect said linnet leaned arms face eager alive dynamic beside joanna southwood seemed somehow little dim tall thin young woman long clever face freakishly plucked eyebrows done much time lots architects things three architects like think ever met right found rather unpractical sometimes darling soon put right practical creature joanna picked string pearls suppose real linnet course know course sweet would people heavily cultured even woolworth darling really incredible exquisitely matched must worth fabulous sums rather vulgar think pure beauty worth fifty thousand lovely lot money afraid stolen always wear anyway insured let wear till darling would give thrill linnet laughed course like know linnet really envy simply got everything twenty mistress amount money looks superb health even got brains next june shall grand party london going marry charles windlesham dreadful little gossip writers getting excited really frightfully devoted linnet shrugged shoulders know really want marry one yet darling right never quite afterwards telephone shrilled linnet went yes yes butler voice answered miss de bellefort line shall put bellefort oh course yes put click voice eager soft slightly breathless voice hallo miss ridgeway heard anything know awful linnet want see darling ca come want well jump train car right frightfully dilapidated ages terribly new toy love show bought fifteen pounds days goes beautifully moods arrived know mood long sweet linnet replaced receiver crossed back joanna oldest friend jacqueline de bellefort together convent paris terribly bad luck father french count mother american southerner father went woman mother lost money wall street crash jackie left absolutely broke know managed get along last two years joanna polishing deep nails friend nail pad leant back head one side scrutinising effect darling drawled wo rather tiresome misfortunes happen friends always drop sounds heartless saves lot trouble later always want borrow money else start business get terrible clothes paint lampshades batik scarves lost money drop tomorrow yes darling would ca say honest like successful people find true nearly everybody people wo admit say ca put mary emily pamela troubles made bitter peculiar poor dear beastly joanna make like eve ...

# %%
#Generate wordcloud using WordCloud Method
wc = WordCloud(background_color = "white").generate(word_string)
plt.axis("off")
plt.imshow(wc)

# %%
masking = np.array(Image.open("hack.jpg"))
plt.axis("off")
wc = WordCloud(mask=masking,background_color="white", contour_width=1,contour_color='black').generate(word_string)
plt.imshow(wc)
